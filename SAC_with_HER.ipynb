# %% [markdown]
# <a href="https://colab.research.google.com/github/maguid28/Deep-Reinforcement-Learning/blob/main/SAC_with_HER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stable Baselines - Hindsight Experience Replay on Highway Env
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
# Highway env: [https://github.com/eleurent/highway-env](https://github.com/eleurent/highway-env)
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a training framework for Reinforcement Learning (RL), using Stable Baselines3.
#
# It provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Install Dependencies and Stable Baselines Using Pip
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# for autoformatting
# %load_ext jupyter_black

# %%
# Install stable-baselines latest version
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# Collecting stable-baselines3>=2.0.0a4 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading stable_baselines3-2.4.0a11-py3-none-any.whl.metadata (4.5 kB)
# Collecting gymnasium<1.1.0,>=0.29.1 (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4)
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.8.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.17.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.66.6)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (13.9.4)
# Collecting ale-py>=0.9.0 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading ale_py-0.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (11.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ale-py>=0.9.0->stable-baselines3[extra]>=2.0.0a4) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<1.1.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.67.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.2)
# Downloading stable_baselines3-2.4.0a11-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 5.1 MB/s eta 0:00:00
# Downloading ale_py-0.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.8 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 14.9 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium, ale-py, stable-baselines3
# Successfully installed ale-py-0.10.1 farama-notifications-0.0.4 gymnasium-1.0.0 stable-baselines3-2.4.0a11

# %%
# Install highway-env
# !pip install highway-env
# Out:
# Collecting highway-env
#   Downloading highway_env-1.10.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: gymnasium>=1.0.0a2 in /usr/local/lib/python3.10/dist-packages (from highway-env) (1.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from highway-env) (0.0.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from highway-env) (1.26.4)
# Requirement already satisfied: pygame>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from highway-env) (2.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from highway-env) (3.8.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from highway-env) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from highway-env) (1.13.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a2->highway-env) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a2->highway-env) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->highway-env) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->highway-env) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->highway-env) (1.16.0)
# Downloading highway_env-1.10.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: highway-env
# Successfully installed highway-env-1.10.1

# %% [markdown]
# ## Import policy, RL agent, ...

# %%
import gymnasium as gym
import highway_env
import numpy as np

from stable_baselines3 import HerReplayBuffer, SAC, DDPG
from stable_baselines3.common.noise import NormalActionNoise

# %% [markdown]
# ## Create the Gym env and instantiate the agent
#
# For this example, we will be using the parking environment from the [highway-env](https://github.com/Farama-Foundation/HighwayEnv) repo by @eleurent.
#
# The parking env is a goal-conditioned continuous control task, in which the vehicle must park in a given space with the appropriate heading.
#
#
# ![parking-env](https://raw.githubusercontent.com/eleurent/highway-env/gh-media/docs/media/parking-env.gif)

# %% [markdown]
# ### Train Soft Actor-Critic (SAC) agent
#
# Here, we use HER "future" goal sampling strategy, where we create 4 artificial transitions per real transition
#
# Note: the hyperparameters (network architecture, discount factor, ...) were tuned for this task

# %%
env = gym.make("parking-v0")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# SAC hyperparams:
model = SAC(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=4,
        goal_selection_strategy="future",
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_rate=1e-3,
    gamma=0.95,
    batch_size=256,
    policy_kwargs=dict(net_arch=[256, 256, 256]),
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train for 1e5 steps
model.learn(int(1e5))
# Save the trained agent
model.save('her_sac_highway')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Streaming output truncated to the last 5000 lines.
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 1896     |
# |    fps             | 39       |
# |    time_elapsed    | 1930     |
# |    total_timesteps | 76815    |
# | train/             |          |
# |    actor_loss      | 1.5      |
# |    critic_loss     | 0.039    |
# |    ent_coef        | 0.0046   |
# |    ent_coef_loss   | -0.358   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 76714    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -6.77    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 39       |
# |    time_elapsed    | 1932     |
# |    total_timesteps | 76884    |
# | train/             |          |
# |    actor_loss      | 1.61     |
# |    critic_loss     | 0.00549  |
# |    ent_coef        | 0.00458  |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 76783    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -6.82    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 1904     |
# |    fps             | 39       |
# |    time_elapsed    | 1934     |
# |    total_timesteps | 76981    |
# | train/             |          |
# |    actor_loss      | 1.46     |
# |    critic_loss     | 0.0137   |
# |    ent_coef        | 0.00453  |
# |    ent_coef_loss   | -0.928   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 76880    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -6.94    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 1908     |
# |    fps             | 39       |
# |    time_elapsed    | 1938     |
# |    total_timesteps | 77119    |
# | train/             |          |
# |    actor_loss      | 1.4      |
# |    critic_loss     | 0.00564  |
# |    ent_coef        | 0.00461  |
# |    ent_coef_loss   | -0.111   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77018    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.03    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 1912     |
# |    fps             | 39       |
# |    time_elapsed    | 1940     |
# |    total_timesteps | 77206    |
# | train/             |          |
# |    actor_loss      | 1.63     |
# |    critic_loss     | 0.00754  |
# |    ent_coef        | 0.0047   |
# |    ent_coef_loss   | 1.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77105    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.09    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 1916     |
# |    fps             | 39       |
# |    time_elapsed    | 1942     |
# |    total_timesteps | 77295    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00717  |
# |    ent_coef        | 0.00466  |
# |    ent_coef_loss   | 0.596    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77194    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -7       |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 1920     |
# |    fps             | 39       |
# |    time_elapsed    | 1944     |
# |    total_timesteps | 77363    |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.0105   |
# |    ent_coef        | 0.00475  |
# |    ent_coef_loss   | 1.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77262    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.03    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 1924     |
# |    fps             | 39       |
# |    time_elapsed    | 1947     |
# |    total_timesteps | 77455    |
# | train/             |          |
# |    actor_loss      | 1.49     |
# |    critic_loss     | 0.01     |
# |    ent_coef        | 0.00481  |
# |    ent_coef_loss   | -0.39    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77354    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.07    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 1928     |
# |    fps             | 39       |
# |    time_elapsed    | 1949     |
# |    total_timesteps | 77544    |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.02     |
# |    ent_coef        | 0.00474  |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77443    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.01    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 1932     |
# |    fps             | 39       |
# |    time_elapsed    | 1950     |
# |    total_timesteps | 77611    |
# | train/             |          |
# |    actor_loss      | 1.78     |
# |    critic_loss     | 0.00513  |
# |    ent_coef        | 0.00468  |
# |    ent_coef_loss   | -0.124   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77510    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.05    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 1936     |
# |    fps             | 39       |
# |    time_elapsed    | 1952     |
# |    total_timesteps | 77700    |
# | train/             |          |
# |    actor_loss      | 1.7      |
# |    critic_loss     | 0.00487  |
# |    ent_coef        | 0.00471  |
# |    ent_coef_loss   | 0.073    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.1     |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 1940     |
# |    fps             | 39       |
# |    time_elapsed    | 1955     |
# |    total_timesteps | 77785    |
# | train/             |          |
# |    actor_loss      | 1.63     |
# |    critic_loss     | 0.0064   |
# |    ent_coef        | 0.00479  |
# |    ent_coef_loss   | 0.458    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77684    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.09    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 1944     |
# |    fps             | 39       |
# |    time_elapsed    | 1957     |
# |    total_timesteps | 77871    |
# | train/             |          |
# |    actor_loss      | 1.61     |
# |    critic_loss     | 0.00433  |
# |    ent_coef        | 0.00485  |
# |    ent_coef_loss   | -1.43    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77770    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.11    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 1948     |
# |    fps             | 39       |
# |    time_elapsed    | 1959     |
# |    total_timesteps | 77956    |
# | train/             |          |
# |    actor_loss      | 1.78     |
# |    critic_loss     | 0.00919  |
# |    ent_coef        | 0.00478  |
# |    ent_coef_loss   | 2.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77855    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 1952     |
# |    fps             | 39       |
# |    time_elapsed    | 1961     |
# |    total_timesteps | 78040    |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.00642  |
# |    ent_coef        | 0.00479  |
# |    ent_coef_loss   | -1.57    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77939    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.21    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 1956     |
# |    fps             | 39       |
# |    time_elapsed    | 1963     |
# |    total_timesteps | 78119    |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.0166   |
# |    ent_coef        | 0.00471  |
# |    ent_coef_loss   | 0.352    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78018    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.28    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 1960     |
# |    fps             | 39       |
# |    time_elapsed    | 1965     |
# |    total_timesteps | 78197    |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.0105   |
# |    ent_coef        | 0.00472  |
# |    ent_coef_loss   | -0.331   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78096    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.29    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 1964     |
# |    fps             | 39       |
# |    time_elapsed    | 1967     |
# |    total_timesteps | 78275    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.0183   |
# |    ent_coef        | 0.00469  |
# |    ent_coef_loss   | 0.379    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78174    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.34    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 1968     |
# |    fps             | 39       |
# |    time_elapsed    | 1970     |
# |    total_timesteps | 78377    |
# | train/             |          |
# |    actor_loss      | 1.74     |
# |    critic_loss     | 0.0072   |
# |    ent_coef        | 0.00465  |
# |    ent_coef_loss   | 0.603    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78276    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.3     |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 1972     |
# |    fps             | 39       |
# |    time_elapsed    | 1972     |
# |    total_timesteps | 78457    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00595  |
# |    ent_coef        | 0.00469  |
# |    ent_coef_loss   | -0.497   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78356    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.32    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 1976     |
# |    fps             | 39       |
# |    time_elapsed    | 1974     |
# |    total_timesteps | 78531    |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.00708  |
# |    ent_coef        | 0.00478  |
# |    ent_coef_loss   | -0.638   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78430    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 1980     |
# |    fps             | 39       |
# |    time_elapsed    | 1976     |
# |    total_timesteps | 78600    |
# | train/             |          |
# |    actor_loss      | 1.76     |
# |    critic_loss     | 0.0295   |
# |    ent_coef        | 0.00477  |
# |    ent_coef_loss   | 0.36     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 1984     |
# |    fps             | 39       |
# |    time_elapsed    | 1978     |
# |    total_timesteps | 78680    |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 0.0214   |
# |    ent_coef        | 0.00464  |
# |    ent_coef_loss   | -0.566   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78579    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.16    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 1988     |
# |    fps             | 39       |
# |    time_elapsed    | 1979     |
# |    total_timesteps | 78745    |
# | train/             |          |
# |    actor_loss      | 1.51     |
# |    critic_loss     | 0.00755  |
# |    ent_coef        | 0.00468  |
# |    ent_coef_loss   | -0.395   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78644    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.13    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 1992     |
# |    fps             | 39       |
# |    time_elapsed    | 1982     |
# |    total_timesteps | 78832    |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.054    |
# |    ent_coef        | 0.00474  |
# |    ent_coef_loss   | -0.17    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78731    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.16    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 1996     |
# |    fps             | 39       |
# |    time_elapsed    | 1984     |
# |    total_timesteps | 78931    |
# | train/             |          |
# |    actor_loss      | 1.95     |
# |    critic_loss     | 0.0107   |
# |    ent_coef        | 0.00461  |
# |    ent_coef_loss   | 1.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78830    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.18    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 39       |
# |    time_elapsed    | 1986     |
# |    total_timesteps | 79005    |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.0259   |
# |    ent_coef        | 0.00468  |
# |    ent_coef_loss   | 0.847    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78904    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.18    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2004     |
# |    fps             | 39       |
# |    time_elapsed    | 1988     |
# |    total_timesteps | 79094    |
# | train/             |          |
# |    actor_loss      | 1.5      |
# |    critic_loss     | 0.0554   |
# |    ent_coef        | 0.00482  |
# |    ent_coef_loss   | -1.61    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78993    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -7.1     |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2008     |
# |    fps             | 39       |
# |    time_elapsed    | 1990     |
# |    total_timesteps | 79185    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.0148   |
# |    ent_coef        | 0.00477  |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79084    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -6.98    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2012     |
# |    fps             | 39       |
# |    time_elapsed    | 1992     |
# |    total_timesteps | 79250    |
# | train/             |          |
# |    actor_loss      | 1.51     |
# |    critic_loss     | 0.00547  |
# |    ent_coef        | 0.0047   |
# |    ent_coef_loss   | -0.281   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79149    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -6.89    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2016     |
# |    fps             | 39       |
# |    time_elapsed    | 1994     |
# |    total_timesteps | 79317    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.00702  |
# |    ent_coef        | 0.0047   |
# |    ent_coef_loss   | 0.569    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79216    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -7.03    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2020     |
# |    fps             | 39       |
# |    time_elapsed    | 1996     |
# |    total_timesteps | 79401    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.008    |
# |    ent_coef        | 0.00481  |
# |    ent_coef_loss   | 1.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79300    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -6.98    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2024     |
# |    fps             | 39       |
# |    time_elapsed    | 1998     |
# |    total_timesteps | 79471    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00539  |
# |    ent_coef        | 0.00479  |
# |    ent_coef_loss   | -0.261   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79370    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.06    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2028     |
# |    fps             | 39       |
# |    time_elapsed    | 2000     |
# |    total_timesteps | 79572    |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.0461   |
# |    ent_coef        | 0.00472  |
# |    ent_coef_loss   | -0.89    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79471    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.2     |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2032     |
# |    fps             | 39       |
# |    time_elapsed    | 2003     |
# |    total_timesteps | 79689    |
# | train/             |          |
# |    actor_loss      | 1.63     |
# |    critic_loss     | 0.00875  |
# |    ent_coef        | 0.00486  |
# |    ent_coef_loss   | 0.212    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79588    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.18    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2036     |
# |    fps             | 39       |
# |    time_elapsed    | 2006     |
# |    total_timesteps | 79782    |
# | train/             |          |
# |    actor_loss      | 1.72     |
# |    critic_loss     | 0.00727  |
# |    ent_coef        | 0.00476  |
# |    ent_coef_loss   | -0.761   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79681    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.12    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2040     |
# |    fps             | 39       |
# |    time_elapsed    | 2008     |
# |    total_timesteps | 79865    |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.0153   |
# |    ent_coef        | 0.00472  |
# |    ent_coef_loss   | -0.49    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79764    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.14    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2044     |
# |    fps             | 39       |
# |    time_elapsed    | 2010     |
# |    total_timesteps | 79953    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.0133   |
# |    ent_coef        | 0.00477  |
# |    ent_coef_loss   | -0.473   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79852    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.09    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2048     |
# |    fps             | 39       |
# |    time_elapsed    | 2012     |
# |    total_timesteps | 80033    |
# | train/             |          |
# |    actor_loss      | 1.83     |
# |    critic_loss     | 0.0113   |
# |    ent_coef        | 0.00461  |
# |    ent_coef_loss   | 0.524    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79932    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | -6.99    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2052     |
# |    fps             | 39       |
# |    time_elapsed    | 2014     |
# |    total_timesteps | 80105    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.0185   |
# |    ent_coef        | 0.00452  |
# |    ent_coef_loss   | 0.455    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80004    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -7.06    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2056     |
# |    fps             | 39       |
# |    time_elapsed    | 2016     |
# |    total_timesteps | 80187    |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.0137   |
# |    ent_coef        | 0.00459  |
# |    ent_coef_loss   | -0.384   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80086    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -7.09    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2060     |
# |    fps             | 39       |
# |    time_elapsed    | 2018     |
# |    total_timesteps | 80263    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.0138   |
# |    ent_coef        | 0.00455  |
# |    ent_coef_loss   | -0.91    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80162    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.13    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2064     |
# |    fps             | 39       |
# |    time_elapsed    | 2021     |
# |    total_timesteps | 80354    |
# | train/             |          |
# |    actor_loss      | 1.63     |
# |    critic_loss     | 0.0111   |
# |    ent_coef        | 0.00465  |
# |    ent_coef_loss   | 0.0018   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80253    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.14    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2068     |
# |    fps             | 39       |
# |    time_elapsed    | 2023     |
# |    total_timesteps | 80453    |
# | train/             |          |
# |    actor_loss      | 1.69     |
# |    critic_loss     | 0.00737  |
# |    ent_coef        | 0.00484  |
# |    ent_coef_loss   | -0.661   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80352    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -7.16    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2072     |
# |    fps             | 39       |
# |    time_elapsed    | 2026     |
# |    total_timesteps | 80561    |
# | train/             |          |
# |    actor_loss      | 1.73     |
# |    critic_loss     | 0.00663  |
# |    ent_coef        | 0.00476  |
# |    ent_coef_loss   | 0.758    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80460    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.15    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2076     |
# |    fps             | 39       |
# |    time_elapsed    | 2027     |
# |    total_timesteps | 80639    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00775  |
# |    ent_coef        | 0.00476  |
# |    ent_coef_loss   | 0.51     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80538    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.21    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2080     |
# |    fps             | 39       |
# |    time_elapsed    | 2030     |
# |    total_timesteps | 80727    |
# | train/             |          |
# |    actor_loss      | 1.75     |
# |    critic_loss     | 0.00595  |
# |    ent_coef        | 0.00485  |
# |    ent_coef_loss   | 0.987    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80626    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.21    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2084     |
# |    fps             | 39       |
# |    time_elapsed    | 2032     |
# |    total_timesteps | 80811    |
# | train/             |          |
# |    actor_loss      | 1.71     |
# |    critic_loss     | 0.00554  |
# |    ent_coef        | 0.00492  |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80710    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.35    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2088     |
# |    fps             | 39       |
# |    time_elapsed    | 2034     |
# |    total_timesteps | 80898    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.0158   |
# |    ent_coef        | 0.00493  |
# |    ent_coef_loss   | -2.46    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80797    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.27    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2092     |
# |    fps             | 39       |
# |    time_elapsed    | 2036     |
# |    total_timesteps | 80969    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.00991  |
# |    ent_coef        | 0.00479  |
# |    ent_coef_loss   | 0.726    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80868    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.24    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2096     |
# |    fps             | 39       |
# |    time_elapsed    | 2039     |
# |    total_timesteps | 81067    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00876  |
# |    ent_coef        | 0.00485  |
# |    ent_coef_loss   | 0.675    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80966    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.34    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 39       |
# |    time_elapsed    | 2041     |
# |    total_timesteps | 81164    |
# | train/             |          |
# |    actor_loss      | 1.51     |
# |    critic_loss     | 0.0129   |
# |    ent_coef        | 0.00495  |
# |    ent_coef_loss   | -1.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81063    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.26    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2104     |
# |    fps             | 39       |
# |    time_elapsed    | 2043     |
# |    total_timesteps | 81248    |
# | train/             |          |
# |    actor_loss      | 1.69     |
# |    critic_loss     | 0.023    |
# |    ent_coef        | 0.00497  |
# |    ent_coef_loss   | 1.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81147    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.29    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2108     |
# |    fps             | 39       |
# |    time_elapsed    | 2046     |
# |    total_timesteps | 81338    |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.00458  |
# |    ent_coef        | 0.00496  |
# |    ent_coef_loss   | 0.558    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81237    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.32    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2112     |
# |    fps             | 39       |
# |    time_elapsed    | 2048     |
# |    total_timesteps | 81414    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.00526  |
# |    ent_coef        | 0.00491  |
# |    ent_coef_loss   | -0.087   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81313    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -7.41    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2116     |
# |    fps             | 39       |
# |    time_elapsed    | 2050     |
# |    total_timesteps | 81507    |
# | train/             |          |
# |    actor_loss      | 1.46     |
# |    critic_loss     | 0.0138   |
# |    ent_coef        | 0.00495  |
# |    ent_coef_loss   | -1.57    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81406    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | -7.29    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2120     |
# |    fps             | 39       |
# |    time_elapsed    | 2052     |
# |    total_timesteps | 81578    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.0087   |
# |    ent_coef        | 0.0049   |
# |    ent_coef_loss   | -0.702   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81477    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | -7.3     |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2124     |
# |    fps             | 39       |
# |    time_elapsed    | 2053     |
# |    total_timesteps | 81644    |
# | train/             |          |
# |    actor_loss      | 1.48     |
# |    critic_loss     | 0.019    |
# |    ent_coef        | 0.00489  |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81543    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.31    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 2128     |
# |    fps             | 39       |
# |    time_elapsed    | 2055     |
# |    total_timesteps | 81736    |
# | train/             |          |
# |    actor_loss      | 1.62     |
# |    critic_loss     | 0.0157   |
# |    ent_coef        | 0.00497  |
# |    ent_coef_loss   | -0.158   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81635    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2132     |
# |    fps             | 39       |
# |    time_elapsed    | 2058     |
# |    total_timesteps | 81831    |
# | train/             |          |
# |    actor_loss      | 1.51     |
# |    critic_loss     | 0.00494  |
# |    ent_coef        | 0.00485  |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81730    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2136     |
# |    fps             | 39       |
# |    time_elapsed    | 2061     |
# |    total_timesteps | 81954    |
# | train/             |          |
# |    actor_loss      | 1.7      |
# |    critic_loss     | 0.0176   |
# |    ent_coef        | 0.00484  |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81853    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | -7.29    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2140     |
# |    fps             | 39       |
# |    time_elapsed    | 2063     |
# |    total_timesteps | 82035    |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 0.013    |
# |    ent_coef        | 0.00491  |
# |    ent_coef_loss   | -1.44    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81934    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.22    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2144     |
# |    fps             | 39       |
# |    time_elapsed    | 2065     |
# |    total_timesteps | 82101    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.00638  |
# |    ent_coef        | 0.00484  |
# |    ent_coef_loss   | -0.765   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.27    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2148     |
# |    fps             | 39       |
# |    time_elapsed    | 2067     |
# |    total_timesteps | 82185    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00938  |
# |    ent_coef        | 0.00477  |
# |    ent_coef_loss   | -0.389   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82084    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.29    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2152     |
# |    fps             | 39       |
# |    time_elapsed    | 2069     |
# |    total_timesteps | 82254    |
# | train/             |          |
# |    actor_loss      | 1.87     |
# |    critic_loss     | 0.0107   |
# |    ent_coef        | 0.00483  |
# |    ent_coef_loss   | 0.621    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82153    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.26    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2156     |
# |    fps             | 39       |
# |    time_elapsed    | 2071     |
# |    total_timesteps | 82346    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.00765  |
# |    ent_coef        | 0.00482  |
# |    ent_coef_loss   | -0.88    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82245    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.19    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2160     |
# |    fps             | 39       |
# |    time_elapsed    | 2073     |
# |    total_timesteps | 82426    |
# | train/             |          |
# |    actor_loss      | 1.67     |
# |    critic_loss     | 0.0192   |
# |    ent_coef        | 0.00483  |
# |    ent_coef_loss   | -0.462   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82325    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.09    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2164     |
# |    fps             | 39       |
# |    time_elapsed    | 2075     |
# |    total_timesteps | 82500    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.00884  |
# |    ent_coef        | 0.00489  |
# |    ent_coef_loss   | 1.41     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.13    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2168     |
# |    fps             | 39       |
# |    time_elapsed    | 2078     |
# |    total_timesteps | 82608    |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.0112   |
# |    ent_coef        | 0.00484  |
# |    ent_coef_loss   | -0.332   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82507    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.14    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2172     |
# |    fps             | 39       |
# |    time_elapsed    | 2080     |
# |    total_timesteps | 82687    |
# | train/             |          |
# |    actor_loss      | 1.62     |
# |    critic_loss     | 0.00595  |
# |    ent_coef        | 0.00493  |
# |    ent_coef_loss   | -0.0853  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82586    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.15    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2176     |
# |    fps             | 39       |
# |    time_elapsed    | 2082     |
# |    total_timesteps | 82770    |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.0107   |
# |    ent_coef        | 0.00495  |
# |    ent_coef_loss   | 0.173    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82669    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.08    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2180     |
# |    fps             | 39       |
# |    time_elapsed    | 2084     |
# |    total_timesteps | 82835    |
# | train/             |          |
# |    actor_loss      | 1.43     |
# |    critic_loss     | 0.014    |
# |    ent_coef        | 0.00498  |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82734    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.06    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2184     |
# |    fps             | 39       |
# |    time_elapsed    | 2086     |
# |    total_timesteps | 82917    |
# | train/             |          |
# |    actor_loss      | 1.67     |
# |    critic_loss     | 0.004    |
# |    ent_coef        | 0.00488  |
# |    ent_coef_loss   | 0.0991   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82816    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.07    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2188     |
# |    fps             | 39       |
# |    time_elapsed    | 2088     |
# |    total_timesteps | 83018    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.0115   |
# |    ent_coef        | 0.00485  |
# |    ent_coef_loss   | 0.0996   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82917    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.1     |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2192     |
# |    fps             | 39       |
# |    time_elapsed    | 2090     |
# |    total_timesteps | 83098    |
# | train/             |          |
# |    actor_loss      | 1.87     |
# |    critic_loss     | 0.00519  |
# |    ent_coef        | 0.00492  |
# |    ent_coef_loss   | 1.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82997    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.08    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2196     |
# |    fps             | 39       |
# |    time_elapsed    | 2092     |
# |    total_timesteps | 83178    |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.0086   |
# |    ent_coef        | 0.005    |
# |    ent_coef_loss   | -0.375   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83077    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -7.09    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 39       |
# |    time_elapsed    | 2094     |
# |    total_timesteps | 83260    |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.0121   |
# |    ent_coef        | 0.00495  |
# |    ent_coef_loss   | -0.481   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83159    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.14    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 2204     |
# |    fps             | 39       |
# |    time_elapsed    | 2096     |
# |    total_timesteps | 83332    |
# | train/             |          |
# |    actor_loss      | 1.69     |
# |    critic_loss     | 0.00693  |
# |    ent_coef        | 0.00488  |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83231    |
# ...
# |    n_updates       | 97772    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | -8.11    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2904     |
# |    fps             | 39       |
# |    time_elapsed    | 2469     |
# |    total_timesteps | 97968    |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 0.00634  |
# |    ent_coef        | 0.00494  |
# |    ent_coef_loss   | -1.66    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97867    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -7.61    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2908     |
# |    fps             | 39       |
# |    time_elapsed    | 2471     |
# |    total_timesteps | 98049    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.00653  |
# |    ent_coef        | 0.00478  |
# |    ent_coef_loss   | -0.292   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97948    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.75    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2912     |
# |    fps             | 39       |
# |    time_elapsed    | 2474     |
# |    total_timesteps | 98142    |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.00592  |
# |    ent_coef        | 0.00481  |
# |    ent_coef_loss   | -0.239   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98041    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.75    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2916     |
# |    fps             | 39       |
# |    time_elapsed    | 2475     |
# |    total_timesteps | 98216    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.00412  |
# |    ent_coef        | 0.00483  |
# |    ent_coef_loss   | 0.922    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98115    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.72    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2920     |
# |    fps             | 39       |
# |    time_elapsed    | 2477     |
# |    total_timesteps | 98286    |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.0192   |
# |    ent_coef        | 0.00494  |
# |    ent_coef_loss   | 0.735    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98185    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.57    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 2924     |
# |    fps             | 39       |
# |    time_elapsed    | 2480     |
# |    total_timesteps | 98376    |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 0.0115   |
# |    ent_coef        | 0.005    |
# |    ent_coef_loss   | -0.795   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98275    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.56    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2928     |
# |    fps             | 39       |
# |    time_elapsed    | 2482     |
# |    total_timesteps | 98458    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.0245   |
# |    ent_coef        | 0.00497  |
# |    ent_coef_loss   | -0.427   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98357    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.6     |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2932     |
# |    fps             | 39       |
# |    time_elapsed    | 2484     |
# |    total_timesteps | 98544    |
# | train/             |          |
# |    actor_loss      | 1.39     |
# |    critic_loss     | 0.00546  |
# |    ent_coef        | 0.00503  |
# |    ent_coef_loss   | 0.0612   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98443    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.51    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2936     |
# |    fps             | 39       |
# |    time_elapsed    | 2486     |
# |    total_timesteps | 98617    |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.00611  |
# |    ent_coef        | 0.00508  |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98516    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -7.55    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2940     |
# |    fps             | 39       |
# |    time_elapsed    | 2487     |
# |    total_timesteps | 98686    |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.00794  |
# |    ent_coef        | 0.005    |
# |    ent_coef_loss   | -0.0701  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98585    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | -7.47    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2944     |
# |    fps             | 39       |
# |    time_elapsed    | 2489     |
# |    total_timesteps | 98756    |
# | train/             |          |
# |    actor_loss      | 1.49     |
# |    critic_loss     | 0.00664  |
# |    ent_coef        | 0.00495  |
# |    ent_coef_loss   | -1.09    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98655    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.33    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2948     |
# |    fps             | 39       |
# |    time_elapsed    | 2491     |
# |    total_timesteps | 98825    |
# | train/             |          |
# |    actor_loss      | 1.62     |
# |    critic_loss     | 0.00728  |
# |    ent_coef        | 0.00494  |
# |    ent_coef_loss   | 0.0491   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98724    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -7.37    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2952     |
# |    fps             | 39       |
# |    time_elapsed    | 2494     |
# |    total_timesteps | 98917    |
# | train/             |          |
# |    actor_loss      | 1.45     |
# |    critic_loss     | 0.0556   |
# |    ent_coef        | 0.00505  |
# |    ent_coef_loss   | -0.943   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98816    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.32    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2956     |
# |    fps             | 39       |
# |    time_elapsed    | 2496     |
# |    total_timesteps | 98996    |
# | train/             |          |
# |    actor_loss      | 1.49     |
# |    critic_loss     | 0.011    |
# |    ent_coef        | 0.00498  |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98895    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -7.34    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 2960     |
# |    fps             | 39       |
# |    time_elapsed    | 2498     |
# |    total_timesteps | 99081    |
# | train/             |          |
# |    actor_loss      | 1.7      |
# |    critic_loss     | 0.00582  |
# |    ent_coef        | 0.0051   |
# |    ent_coef_loss   | -0.127   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98980    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -7.26    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2964     |
# |    fps             | 39       |
# |    time_elapsed    | 2500     |
# |    total_timesteps | 99161    |
# | train/             |          |
# |    actor_loss      | 1.71     |
# |    critic_loss     | 0.00666  |
# |    ent_coef        | 0.00515  |
# |    ent_coef_loss   | 0.839    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99060    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.26    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2968     |
# |    fps             | 39       |
# |    time_elapsed    | 2502     |
# |    total_timesteps | 99247    |
# | train/             |          |
# |    actor_loss      | 1.61     |
# |    critic_loss     | 0.00542  |
# |    ent_coef        | 0.00518  |
# |    ent_coef_loss   | 0.589    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99146    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -7.21    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2972     |
# |    fps             | 39       |
# |    time_elapsed    | 2504     |
# |    total_timesteps | 99321    |
# | train/             |          |
# |    actor_loss      | 1.71     |
# |    critic_loss     | 0.00716  |
# |    ent_coef        | 0.00519  |
# |    ent_coef_loss   | 0.969    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99220    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.28    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2976     |
# |    fps             | 39       |
# |    time_elapsed    | 2506     |
# |    total_timesteps | 99403    |
# | train/             |          |
# |    actor_loss      | 1.76     |
# |    critic_loss     | 0.01     |
# |    ent_coef        | 0.00506  |
# |    ent_coef_loss   | 0.348    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99302    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.36    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2980     |
# |    fps             | 39       |
# |    time_elapsed    | 2508     |
# |    total_timesteps | 99489    |
# | train/             |          |
# |    actor_loss      | 1.72     |
# |    critic_loss     | 0.0244   |
# |    ent_coef        | 0.00497  |
# |    ent_coef_loss   | 0.336    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99388    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | -7.3     |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2984     |
# |    fps             | 39       |
# |    time_elapsed    | 2510     |
# |    total_timesteps | 99559    |
# | train/             |          |
# |    actor_loss      | 1.8      |
# |    critic_loss     | 0.0108   |
# |    ent_coef        | 0.00513  |
# |    ent_coef_loss   | 2.69     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99458    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -7.38    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2988     |
# |    fps             | 39       |
# |    time_elapsed    | 2512     |
# |    total_timesteps | 99651    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.00638  |
# |    ent_coef        | 0.00518  |
# |    ent_coef_loss   | 0.954    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99550    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -7.4     |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2992     |
# |    fps             | 39       |
# |    time_elapsed    | 2514     |
# |    total_timesteps | 99730    |
# | train/             |          |
# |    actor_loss      | 1.69     |
# |    critic_loss     | 0.0241   |
# |    ent_coef        | 0.00512  |
# |    ent_coef_loss   | 0.123    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99629    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.48    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 2996     |
# |    fps             | 39       |
# |    time_elapsed    | 2516     |
# |    total_timesteps | 99821    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00541  |
# |    ent_coef        | 0.00528  |
# |    ent_coef_loss   | 0.651    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99720    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.46    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 39       |
# |    time_elapsed    | 2519     |
# |    total_timesteps | 99891    |
# | train/             |          |
# |    actor_loss      | 1.42     |
# |    critic_loss     | 0.00564  |
# |    ent_coef        | 0.00528  |
# |    ent_coef_loss   | -0.593   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99790    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.34    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3004     |
# |    fps             | 39       |
# |    time_elapsed    | 2521     |
# |    total_timesteps | 99986    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.00893  |
# |    ent_coef        | 0.00531  |
# |    ent_coef_loss   | -0.648   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99885    |
# ---------------------------------

# %%
# Load saved model
model = SAC.load('her_sac_highway', env=env)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# #### Evaluate the agent

# %%
# we use the gym >v.26 API here. Note that you could also wrap the env in a DummyVecEnv
# which allows you to use a simplified API
obs, _ = env.reset()

# Evaluate the agent
episode_reward = 0
for _ in range(1000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = truncated or terminated
    episode_reward += reward
    if done or info.get("is_success", False):
        print("Reward:", episode_reward, "Success?", info.get("is_success", False))
        episode_reward = 0.0
        obs, _ = env.reset()
# Out:
# Reward: -2.355129741427345 Success? True
# Reward: -9.081994387895351 Success? True
# Reward: -2.2852601007293827 Success? True
# Reward: -4.675070981726117 Success? True
# Reward: -5.115426798700607 Success? True
# Reward: -4.259585992408998 Success? True
# Reward: -3.3722954832556766 Success? True
# Reward: -4.427494844392133 Success? True
# Reward: -12.054428444829757 Success? True
# Reward: -7.695538667586793 Success? True
# Reward: -5.34783251796113 Success? True
# Reward: -7.879838793682838 Success? True
# Reward: -7.199446795778505 Success? True
# Reward: -4.743820351324023 Success? True
# Reward: -10.057539438522307 Success? True
# Reward: -7.434510674777588 Success? True
# Reward: -6.686455333443665 Success? True
# Reward: -4.730047082631324 Success? True
# Reward: -10.604326538825276 Success? True
# Reward: -3.45660062655118 Success? True
# Reward: -7.785878768166735 Success? True
# Reward: -9.495165920763398 Success? True
# Reward: -5.054197758135411 Success? True
# Reward: -11.12064554140158 Success? False
# Reward: -5.565846406091378 Success? True
# Reward: -5.560068704325016 Success? True
# Reward: -8.498523953591205 Success? True
# Reward: -10.26755590947926 Success? True
# Reward: -2.5393674148846657 Success? True
# Reward: -6.29881695562945 Success? True
# Reward: -4.173923604846611 Success? True
# Reward: -8.354715250597085 Success? True
# Reward: -4.161794447012586 Success? True
# Reward: -11.05157886525921 Success? False
# Reward: -5.779945821979433 Success? True
# Reward: -11.845502869542226 Success? False
# Reward: -4.568569348095633 Success? True
# Reward: -5.930012119575403 Success? True
# Reward: -6.26455408884858 Success? True
# Reward: -6.398343208747634 Success? True
# Reward: -7.5154053408502035 Success? True
# Reward: -7.140926351307689 Success? True
# Reward: -9.442867849355471 Success? True
# Reward: -4.34285820118139 Success? True
# Reward: -7.501048664009776 Success? True
# Reward: -9.087125738680463 Success? True
# Reward: -11.551538371624655 Success? True
# Reward: -6.829520862437688 Success? True
# Reward: -5.369965880277822 Success? True

# %% [markdown]
# ### Train DDPG agent

# %%
# Create the action noise object that will be used for exploration
n_actions = env.action_space.shape[0]
noise_std = 0.2
action_noise = NormalActionNoise(
    mean=np.zeros(n_actions), sigma=noise_std * np.ones(n_actions)
)

model = DDPG(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=4,
        goal_selection_strategy="future",
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_rate=1e-3,
    action_noise=action_noise,
    gamma=0.95,
    batch_size=256,
    policy_kwargs=dict(net_arch=[256, 256, 256]),
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train for 2e5 steps
model.learn(int(2e5))
# Save the trained agent
model.save('her_ddpg_highway')
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.2     |
# |    ep_rew_mean     | -33.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 71       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 225      |
# | train/             |          |
# |    actor_loss      | 0.338    |
# |    critic_loss     | 0.0322   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 124      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.6     |
# |    ep_rew_mean     | -31.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 56       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 453      |
# | train/             |          |
# |    actor_loss      | 0.528    |
# |    critic_loss     | 0.0192   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 352      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | -80.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 53       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 1945     |
# | train/             |          |
# |    actor_loss      | 0.965    |
# |    critic_loss     | 0.00414  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1844     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | -67.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 53       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 2190     |
# | train/             |          |
# |    actor_loss      | 1.11     |
# |    critic_loss     | 0.00706  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2089     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 115      |
# |    ep_rew_mean     | -57.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 54       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 2294     |
# | train/             |          |
# |    actor_loss      | 1.13     |
# |    critic_loss     | 0.00526  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2193     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | -68.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 53       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 3379     |
# | train/             |          |
# |    actor_loss      | 1.31     |
# |    critic_loss     | 0.00544  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3278     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | -63      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 53       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00948  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | -59.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 53       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 3855     |
# | train/             |          |
# |    actor_loss      | 1.23     |
# |    critic_loss     | 0.00644  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3754     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | -68.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 53       |
# |    time_elapsed    | 92       |
# |    total_timesteps | 4918     |
# | train/             |          |
# |    actor_loss      | 1.21     |
# |    critic_loss     | 0.00323  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4817     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | -68.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 53       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 5494     |
# | train/             |          |
# |    actor_loss      | 1.36     |
# |    critic_loss     | 0.00529  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5393     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | -65.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 53       |
# |    time_elapsed    | 115      |
# |    total_timesteps | 6132     |
# | train/             |          |
# |    actor_loss      | 1.4      |
# |    critic_loss     | 0.00492  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6031     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -66.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 53       |
# |    time_elapsed    | 128      |
# |    total_timesteps | 6803     |
# | train/             |          |
# |    actor_loss      | 1.26     |
# |    critic_loss     | 0.00866  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6702     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | -66      |
# |    success_rate    | 0.0192   |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 52       |
# |    time_elapsed    | 140      |
# |    total_timesteps | 7417     |
# | train/             |          |
# |    actor_loss      | 1.27     |
# |    critic_loss     | 0.00861  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7316     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | -67.6    |
# |    success_rate    | 0.0179   |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 52       |
# |    time_elapsed    | 152      |
# |    total_timesteps | 8056     |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00565  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7955     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 159      |
# |    ep_rew_mean     | -69.6    |
# |    success_rate    | 0.0167   |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 52       |
# |    time_elapsed    | 180      |
# |    total_timesteps | 9521     |
# | train/             |          |
# |    actor_loss      | 1.45     |
# |    critic_loss     | 0.00472  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9420     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 158      |
# |    ep_rew_mean     | -67.6    |
# |    success_rate    | 0.0312   |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 52       |
# |    time_elapsed    | 191      |
# |    total_timesteps | 10116    |
# | train/             |          |
# |    actor_loss      | 1.41     |
# |    critic_loss     | 0.00495  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10015    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 157      |
# |    ep_rew_mean     | -66      |
# |    success_rate    | 0.0294   |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 52       |
# |    time_elapsed    | 202      |
# |    total_timesteps | 10694    |
# | train/             |          |
# |    actor_loss      | 1.41     |
# |    critic_loss     | 0.0474   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10593    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 156      |
# |    ep_rew_mean     | -64.5    |
# |    success_rate    | 0.0278   |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 52       |
# |    time_elapsed    | 213      |
# |    total_timesteps | 11263    |
# | train/             |          |
# |    actor_loss      | 1.4      |
# |    critic_loss     | 0.00475  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11162    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -62      |
# |    success_rate    | 0.0263   |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 52       |
# |    time_elapsed    | 216      |
# |    total_timesteps | 11405    |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.00573  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11304    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | -59.8    |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 52       |
# |    time_elapsed    | 218      |
# |    total_timesteps | 11533    |
# | train/             |          |
# |    actor_loss      | 1.38     |
# |    critic_loss     | 0.00618  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11432    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | -62.1    |
# |    success_rate    | 0.0238   |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 52       |
# |    time_elapsed    | 246      |
# |    total_timesteps | 13036    |
# | train/             |          |
# |    actor_loss      | 1.38     |
# |    critic_loss     | 0.00521  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12935    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 149      |
# |    ep_rew_mean     | -60.1    |
# |    success_rate    | 0.0227   |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 52       |
# |    time_elapsed    | 248      |
# |    total_timesteps | 13152    |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.00324  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13051    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 145      |
# |    ep_rew_mean     | -58.4    |
# |    success_rate    | 0.0326   |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 52       |
# |    time_elapsed    | 253      |
# |    total_timesteps | 13363    |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.00474  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13262    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | -56.9    |
# |    success_rate    | 0.0312   |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 52       |
# |    time_elapsed    | 256      |
# |    total_timesteps | 13517    |
# | train/             |          |
# |    actor_loss      | 1.39     |
# |    critic_loss     | 0.00538  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13416    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -55.2    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 52       |
# |    time_elapsed    | 258      |
# |    total_timesteps | 13611    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.018    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13510    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 135      |
# |    ep_rew_mean     | -54.4    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 52       |
# |    time_elapsed    | 259      |
# |    total_timesteps | 13709    |
# | train/             |          |
# |    actor_loss      | 1.42     |
# |    critic_loss     | 0.00431  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13608    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | -55      |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 52       |
# |    time_elapsed    | 271      |
# |    total_timesteps | 14282    |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.00564  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14181    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 131      |
# |    ep_rew_mean     | -49.8    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 52       |
# |    time_elapsed    | 285      |
# |    total_timesteps | 15029    |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.00627  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14928    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | -49.4    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 52       |
# |    time_elapsed    | 288      |
# |    total_timesteps | 15157    |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.00777  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15056    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -51.4    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 52       |
# |    time_elapsed    | 314      |
# |    total_timesteps | 16509    |
# | train/             |          |
# |    actor_loss      | 1.45     |
# |    critic_loss     | 0.00394  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16408    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 134      |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 52       |
# |    time_elapsed    | 319      |
# |    total_timesteps | 16754    |
# | train/             |          |
# |    actor_loss      | 1.37     |
# |    critic_loss     | 0.00786  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16653    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | -46.9    |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 52       |
# |    time_elapsed    | 331      |
# |    total_timesteps | 17336    |
# | train/             |          |
# |    actor_loss      | 1.48     |
# |    critic_loss     | 0.00373  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17235    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | -46.9    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 52       |
# |    time_elapsed    | 343      |
# |    total_timesteps | 17950    |
# | train/             |          |
# |    actor_loss      | 1.46     |
# |    critic_loss     | 0.00409  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17849    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -43.5    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 52       |
# |    time_elapsed    | 365      |
# |    total_timesteps | 19105    |
# | train/             |          |
# |    actor_loss      | 1.39     |
# |    critic_loss     | 0.00244  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19004    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 146      |
# |    ep_rew_mean     | -43.3    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 52       |
# |    time_elapsed    | 384      |
# |    total_timesteps | 20139    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.00356  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20038    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 146      |
# |    ep_rew_mean     | -43.7    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 52       |
# |    time_elapsed    | 397      |
# |    total_timesteps | 20763    |
# | train/             |          |
# |    actor_loss      | 1.42     |
# |    critic_loss     | 0.00547  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20662    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 149      |
# |    ep_rew_mean     | -42.4    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 52       |
# |    time_elapsed    | 415      |
# |    total_timesteps | 21698    |
# | train/             |          |
# |    actor_loss      | 1.41     |
# |    critic_loss     | 0.0177   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21597    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 149      |
# |    ep_rew_mean     | -41.4    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 52       |
# |    time_elapsed    | 428      |
# |    total_timesteps | 22363    |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.00305  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22262    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -39.4    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 52       |
# |    time_elapsed    | 441      |
# |    total_timesteps | 23067    |
# | train/             |          |
# |    actor_loss      | 1.36     |
# |    critic_loss     | 0.00629  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22966    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 151      |
# |    ep_rew_mean     | -38.1    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 52       |
# |    time_elapsed    | 471      |
# |    total_timesteps | 24591    |
# | train/             |          |
# |    actor_loss      | 1.29     |
# |    critic_loss     | 0.00494  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24490    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 146      |
# |    ep_rew_mean     | -37.1    |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 52       |
# |    time_elapsed    | 474      |
# |    total_timesteps | 24703    |
# | train/             |          |
# |    actor_loss      | 1.39     |
# |    critic_loss     | 0.00384  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24602    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | -36.5    |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 52       |
# |    time_elapsed    | 482      |
# |    total_timesteps | 25140    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00393  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25039    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | -35.4    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 52       |
# |    time_elapsed    | 485      |
# |    total_timesteps | 25262    |
# | train/             |          |
# |    actor_loss      | 1.39     |
# |    critic_loss     | 0.00585  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25161    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | -35.1    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 52       |
# |    time_elapsed    | 487      |
# |    total_timesteps | 25379    |
# | train/             |          |
# |    actor_loss      | 1.41     |
# |    critic_loss     | 0.00585  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25278    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | -35.5    |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 52       |
# |    time_elapsed    | 498      |
# |    total_timesteps | 25917    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00428  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25816    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -31.9    |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 52       |
# |    time_elapsed    | 504      |
# |    total_timesteps | 26290    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00425  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26189    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | -32.1    |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 52       |
# |    time_elapsed    | 515      |
# |    total_timesteps | 26847    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00394  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26746    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -31.7    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 52       |
# |    time_elapsed    | 517      |
# |    total_timesteps | 26935    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00337  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26834    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 135      |
# |    ep_rew_mean     | -31.2    |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 52       |
# |    time_elapsed    | 519      |
# |    total_timesteps | 27030    |
# | train/             |          |
# |    actor_loss      | 1.3      |
# |    critic_loss     | 0.00454  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26929    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | -32      |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 51       |
# |    time_elapsed    | 532      |
# |    total_timesteps | 27693    |
# | train/             |          |
# |    actor_loss      | 1.37     |
# |    critic_loss     | 0.00487  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27592    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -33.8    |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 51       |
# |    time_elapsed    | 553      |
# |    total_timesteps | 28756    |
# | train/             |          |
# |    actor_loss      | 1.27     |
# |    critic_loss     | 0.00935  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28655    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 154      |
# |    ep_rew_mean     | -33.6    |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 51       |
# |    time_elapsed    | 570      |
# |    total_timesteps | 29642    |
# | train/             |          |
# |    actor_loss      | 1.4      |
# |    critic_loss     | 0.00735  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29541    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 148      |
# |    ep_rew_mean     | -32.4    |
# |    success_rate    | 0.42     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 51       |
# |    time_elapsed    | 573      |
# |    total_timesteps | 29810    |
# | train/             |          |
# |    actor_loss      | 1.32     |
# |    critic_loss     | 0.00521  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29709    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 156      |
# |    ep_rew_mean     | -33.7    |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 51       |
# |    time_elapsed    | 592      |
# |    total_timesteps | 30804    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.00439  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | -33.1    |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 51       |
# |    time_elapsed    | 616      |
# |    total_timesteps | 31971    |
# | train/             |          |
# |    actor_loss      | 1.32     |
# |    critic_loss     | 0.00343  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31870    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 158      |
# |    ep_rew_mean     | -33.6    |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 51       |
# |    time_elapsed    | 627      |
# |    total_timesteps | 32547    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00275  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 32446    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 154      |
# |    ep_rew_mean     | -33.1    |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 51       |
# |    time_elapsed    | 630      |
# |    total_timesteps | 32716    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.00315  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 32615    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 158      |
# |    ep_rew_mean     | -33.5    |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 51       |
# |    time_elapsed    | 652      |
# |    total_timesteps | 33770    |
# | train/             |          |
# |    actor_loss      | 1.36     |
# |    critic_loss     | 0.0046   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 33669    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | -32.4    |
# |    success_rate    | 0.47     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 51       |
# |    time_elapsed    | 663      |
# |    total_timesteps | 34339    |
# | train/             |          |
# |    actor_loss      | 1.29     |
# |    critic_loss     | 0.0036   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 34238    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 151      |
# |    ep_rew_mean     | -31.3    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 51       |
# |    time_elapsed    | 681      |
# |    total_timesteps | 35270    |
# | train/             |          |
# |    actor_loss      | 1.2      |
# |    critic_loss     | 0.00217  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35169    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 151      |
# |    ep_rew_mean     | -30.6    |
# |    success_rate    | 0.51     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 51       |
# |    time_elapsed    | 694      |
# |    total_timesteps | 35888    |
# | train/             |          |
# |    actor_loss      | 1.27     |
# |    critic_loss     | 0.00447  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35787    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | -29.1    |
# |    success_rate    | 0.54     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 51       |
# |    time_elapsed    | 695      |
# |    total_timesteps | 35980    |
# | train/             |          |
# |    actor_loss      | 1.26     |
# |    critic_loss     | 0.00536  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35879    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | -28.1    |
# |    success_rate    | 0.56     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 51       |
# |    time_elapsed    | 699      |
# |    total_timesteps | 36115    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00949  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36014    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 132      |
# |    ep_rew_mean     | -27.1    |
# |    success_rate    | 0.56     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 51       |
# |    time_elapsed    | 702      |
# |    total_timesteps | 36301    |
# | train/             |          |
# |    actor_loss      | 1.36     |
# |    critic_loss     | 0.00566  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36200    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | -24.8    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 51       |
# |    time_elapsed    | 704      |
# |    total_timesteps | 36403    |
# | train/             |          |
# |    actor_loss      | 1.17     |
# |    critic_loss     | 0.00389  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36302    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | -24.6    |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 51       |
# |    time_elapsed    | 706      |
# |    total_timesteps | 36507    |
# | train/             |          |
# |    actor_loss      | 1.2      |
# |    critic_loss     | 0.00733  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36406    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 114      |
# |    ep_rew_mean     | -24      |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 51       |
# |    time_elapsed    | 708      |
# |    total_timesteps | 36589    |
# | train/             |          |
# |    actor_loss      | 1.26     |
# |    critic_loss     | 0.00594  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36488    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | -24.3    |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 51       |
# |    time_elapsed    | 714      |
# |    total_timesteps | 36878    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00401  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36777    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -25      |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 51       |
# |    time_elapsed    | 727      |
# |    total_timesteps | 37528    |
# | train/             |          |
# |    actor_loss      | 1.27     |
# |    critic_loss     | 0.00708  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37427    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | -25.7    |
# |    success_rate    | 0.61     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 51       |
# |    time_elapsed    | 747      |
# |    total_timesteps | 38583    |
# | train/             |          |
# |    actor_loss      | 1.23     |
# |    critic_loss     | 0.00369  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 38482    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | -25.4    |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 51       |
# |    time_elapsed    | 751      |
# |    total_timesteps | 38765    |
# | train/             |          |
# |    actor_loss      | 1.23     |
# |    critic_loss     | 0.00249  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 38664    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -24.9    |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 51       |
# |    time_elapsed    | 755      |
# |    total_timesteps | 38938    |
# | train/             |          |
# |    actor_loss      | 1.23     |
# |    critic_loss     | 0.00525  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 38837    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | -25.6    |
# |    success_rate    | 0.64     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 51       |
# |    time_elapsed    | 767      |
# |    total_timesteps | 39563    |
# | train/             |          |
# |    actor_loss      | 1.3      |
# |    critic_loss     | 0.00475  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39462    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | -25.7    |
# |    success_rate    | 0.63     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 51       |
# |    time_elapsed    | 769      |
# |    total_timesteps | 39676    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.00477  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39575    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -24.8    |
# |    success_rate    | 0.64     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 51       |
# |    time_elapsed    | 772      |
# |    total_timesteps | 39842    |
# | train/             |          |
# |    actor_loss      | 1.28     |
# |    critic_loss     | 0.00394  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39741    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -24.3    |
# |    success_rate    | 0.64     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 51       |
# |    time_elapsed    | 789      |
# |    total_timesteps | 40633    |
# | train/             |          |
# |    actor_loss      | 1.4      |
# |    critic_loss     | 0.0036   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 40532    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | -24.4    |
# |    success_rate    | 0.66     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 51       |
# |    time_elapsed    | 804      |
# |    total_timesteps | 41435    |
# | train/             |          |
# |    actor_loss      | 1.21     |
# |    critic_loss     | 0.00344  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 41334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | -24.4    |
# |    success_rate    | 0.67     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 51       |
# |    time_elapsed    | 811      |
# |    total_timesteps | 41781    |
# | train/             |          |
# |    actor_loss      | 1.31     |
# |    critic_loss     | 0.00765  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 41680    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0.68     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 51       |
# |    time_elapsed    | 814      |
# |    total_timesteps | 41912    |
# | train/             |          |
# |    actor_loss      | 1.18     |
# |    critic_loss     | 0.00703  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 41811    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -21.1    |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 51       |
# |    time_elapsed    | 816      |
# |    total_timesteps | 42006    |
# | train/             |          |
# |    actor_loss      | 1.27     |
# |    critic_loss     | 0.00488  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 41905    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.8     |
# |    ep_rew_mean     | -20.5    |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 51       |
# |    time_elapsed    | 818      |
# |    total_timesteps | 42130    |
# | train/             |          |
# |    actor_loss      | 1.36     |
# |    critic_loss     | 0.0103   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 42029    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.5     |
# |    ep_rew_mean     | -20.5    |
# |    success_rate    | 0.71     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 51       |
# |    time_elapsed    | 821      |
# |    total_timesteps | 42269    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.0048   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 42168    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.1     |
# |    ep_rew_mean     | -19      |
# |    success_rate    | 0.73     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 51       |
# |    time_elapsed    | 823      |
# |    total_timesteps | 42380    |
# | train/             |          |
# |    actor_loss      | 1.1      |
# |    critic_loss     | 0.00338  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 42279    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.4     |
# |    ep_rew_mean     | -18.3    |
# |    success_rate    | 0.74     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 51       |
# |    time_elapsed    | 827      |
# |    total_timesteps | 42576    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.00584  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 42475    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.2     |
# |    ep_rew_mean     | -17.4    |
# |    success_rate    | 0.75     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 51       |
# |    time_elapsed    | 831      |
# |    total_timesteps | 42789    |
# | train/             |          |
# |    actor_loss      | 1.19     |
# |    critic_loss     | 0.00572  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 42688    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.6     |
# |    ep_rew_mean     | -16.7    |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 51       |
# |    time_elapsed    | 834      |
# |    total_timesteps | 42952    |
# | train/             |          |
# |    actor_loss      | 1.31     |
# |    critic_loss     | 0.00363  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 42851    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.8     |
# |    ep_rew_mean     | -17.2    |
# |    success_rate    | 0.76     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 51       |
# |    time_elapsed    | 841      |
# |    total_timesteps | 43265    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00361  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43164    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.2     |
# |    ep_rew_mean     | -17.2    |
# |    success_rate    | 0.75     |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 51       |
# |    time_elapsed    | 842      |
# |    total_timesteps | 43339    |
# | train/             |          |
# |    actor_loss      | 1.31     |
# |    critic_loss     | 0.00363  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43238    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.3     |
# |    ep_rew_mean     | -17      |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 51       |
# |    time_elapsed    | 846      |
# |    total_timesteps | 43536    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.00876  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43435    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.3     |
# |    ep_rew_mean     | -17.1    |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 51       |
# |    time_elapsed    | 848      |
# |    total_timesteps | 43632    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00444  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43531    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.8     |
# |    ep_rew_mean     | -17.3    |
# |    success_rate    | 0.77     |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 51       |
# |    time_elapsed    | 853      |
# |    total_timesteps | 43889    |
# | train/             |          |
# |    actor_loss      | 1.37     |
# |    critic_loss     | 0.0069   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43788    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.8     |
# |    ep_rew_mean     | -17.3    |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 51       |
# |    time_elapsed    | 857      |
# |    total_timesteps | 44073    |
# | train/             |          |
# |    actor_loss      | 1.26     |
# |    critic_loss     | 0.00481  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43972    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.3     |
# |    ep_rew_mean     | -17.2    |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 51       |
# |    time_elapsed    | 864      |
# |    total_timesteps | 44411    |
# | train/             |          |
# |    actor_loss      | 1.26     |
# |    critic_loss     | 0.00358  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 44310    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 69.7     |
# |    ep_rew_mean     | -16.4    |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 51       |
# |    time_elapsed    | 865      |
# |    total_timesteps | 44497    |
# | train/             |          |
# |    actor_loss      | 1.18     |
# |    critic_loss     | 0.00355  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 44396    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.8     |
# |    ep_rew_mean     | -15.8    |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 51       |
# |    time_elapsed    | 877      |
# |    total_timesteps | 45062    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.0192   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 44961    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.7     |
# |    ep_rew_mean     | -15.5    |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 51       |
# |    time_elapsed    | 878      |
# |    total_timesteps | 45135    |
# | train/             |          |
# |    actor_loss      | 1.38     |
# |    critic_loss     | 0.00409  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 45034    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63       |
# |    ep_rew_mean     | -15.5    |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 51       |
# |    time_elapsed    | 880      |
# |    total_timesteps | 45240    |
# | train/             |          |
# |    actor_loss      | 1.32     |
# |    critic_loss     | 0.00514  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 45139    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.1     |
# |    ep_rew_mean     | -14.8    |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 51       |
# |    time_elapsed    | 884      |
# |    total_timesteps | 45469    |
# | train/             |          |
# |    actor_loss      | 1.19     |
# |    critic_loss     | 0.00994  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 45368    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.9     |
# |    ep_rew_mean     | -14.8    |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 51       |
# |    time_elapsed    | 888      |
# |    total_timesteps | 45663    |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.00419  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 45562    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.7     |
# |    ep_rew_mean     | -14.8    |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 51       |
# |    time_elapsed    | 892      |
# |    total_timesteps | 45812    |
# | train/             |          |
# |    actor_loss      | 1.41     |
# |    critic_loss     | 0.0167   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 45711    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.3     |
# |    ep_rew_mean     | -13.4    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 51       |
# |    time_elapsed    | 894      |
# |    total_timesteps | 45963    |
# | train/             |          |
# |    actor_loss      | 1.29     |
# |    critic_loss     | 0.00327  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 45862    |
# ---------------------------------

# %%
# Load saved model
model = DDPG.load('her_ddpg_highway', env=env)

# %% [markdown]
# #### Evaluate the agent

# %%
# we use the gym >v.26 API here. Note that you could also wrap the env in a DummyVecEnv
# which allows you to use the old gym API a simplified API
obs, _ = env.reset()

# Evaluate the agent
episode_reward = 0
for _ in range(1000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = truncated or terminated
    episode_reward += reward
    if done or info.get("is_success", False):
        print("Reward:", episode_reward, "Success?", info.get("is_success", False))
        episode_reward = 0.0
        obs, _ = env.reset()
